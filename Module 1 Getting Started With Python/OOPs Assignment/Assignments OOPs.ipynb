# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Employee():
    
    def __init__(self):
        self.EmployeeID = 'E000'
        self.Gender = 'Male'
        self.Salary = 0
        self.PerformanceRating = 0
        
    def get(self, EmployeeID:str, Gender:str, Salary:int, PerformanceRating:int):
        assert type(EmployeeID) ==str, "Please provide valid string of Employee ID"
        assert (type(Gender) == str) and (Gender == 'Male' or Gender == 'Female'), "Please enter valid value from ['Male' or 'Female']"
        assert type(Salary) ==int, "Please provide valid integer"
        assert (type(PerformanceRating) == int) and (0<= PerformanceRating <=5), "Please provide valid rating between 0 to 5"
        
        self.EmployeeID = EmployeeID
        self.Gender = Gender
        self.Salary = Salary
        self.PerformanceRating = PerformanceRating

# %%
e = Employee()

# %%
e.get('abc01','Male',300,3)

# %%
e.pr()
# Out:
# abc01 Male 300 3

# %%
class Employee:

    def __init__(self,EmployeeID,Gender,Salary,PerformanceRating):
        assert type(EmployeeID) ==str, "Please provide valid string of Employee ID"
        assert (type(Gender) == str) and (Gender == 'Male' or Gender == 'Female'), "Please enter valid value from ['Male' or 'Female']"
        assert type(Salary) ==int, "Please provide valid integer"
        assert (type(PerformanceRating) == int) and (0<= PerformanceRating <=5), "Please provide valid rating between 0 to 5"
        
        self.EmployeeID = EmployeeID
        self.Gender = Gender
        self.Salary = Salary
        self.PerformanceRating = PerformanceRating

    def get_details(self):
        print ("\nEmployeeID :",self.EmployeeID)
        print ("Gender :",self.Gender)
        print ("Salary :",self.Salary)
        print ("PerformanceRating :",self.PerformanceRating,"\n")


class JoiningDetail():

    def __init__(self,DateOfJoining):
        self.DateOfJoining= DateOfJoining

    def getDOJ(self):
        print ("DateOfJoining :",self.DateOfJoining,"\n")


class Information(Employee,JoiningDetail):

    def __init__(self,EmployeeID,Gender,Salary,PerformanceRating,DateOfJoining):
        Employee.__init__(self,EmployeeID,Gender,Salary,PerformanceRating)
        JoiningDetail.__init__(self,DateOfJoining)

    def readData(self):
        print("Incomplete")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Vehicle: 
    def __init__(self, fare): 
        self.fare = fare 
    def Fare(self): 
        return self.fare
    
Bus = Vehicle(100) 
Car = Vehicle(80) 
Train = Vehicle(50) 
Truck = Vehicle(520) 
Ship = Vehicle(750) 
Bus.Fare() 
Car.Fare() 
Train.Fare() 
Truck.Fare() 
Ship.Fare()

TotalFare = (Bus.Fare() + Car.Fare() + Train.Fare() + Truck.Fare() + Ship.Fare()) 
print(Bus.Fare(), Car.Fare(),Train.Fare(), Truck.Fare(), Ship.Fare()) 
print(TotalFare)
# Out:
# 100 80 50 520 750
# 1500

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def Max_Score(leaderboard):
    score = {}

    for match in lb.items():

        for key in match[1].keys():

            if key in score.keys():
                sc = match[1].get(key)
                score[key] = score.get(key) + sc
            else:
                score[key] = match[1].get(key)
                
    player = sorted(score)[0]
    sc = score.get(player)
    print(f"Total maximum {sc} runs are scored by {player}")

    return (player, sc)

# %%
lb ={'test1':{'Dhoni':56, 'Balaji' : 85}, 
     'test2':{'Dhoni': 87, 'Balaji':200}}

# %%
Max_Score(lb)
# Out:
# Total maximum 285 runs are scored by Balaji
# ('Balaji', 285)

# %% [markdown]
# ![image.png](attachment:image.png)
